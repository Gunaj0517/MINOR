# %%
import pandas as pd

# %%
df=pd.read_csv('predictions.csv')

# %%
df.head()
# Out:
#   video_id  frame_idx   timestamp gt_label pred_label  pred_score   avg_ear  \
# 0     live          0  1761384467    awake      awake    0.238960  0.238960
# 1     live          1  1761384467    awake      awake    0.285675  0.285675
# 2     live          2  1761384468    awake      awake    0.299466  0.299466
# 3     live          3  1761384468    awake      awake    0.305160  0.305160
# 4     live          4  1761384468    awake      awake    0.299087  0.299087
#
#         mar  gamma_used
# 0  0.019593           0
# 1  0.018868           0
# 2  0.019996           0
# 3  0.000000           0
# 4  0.000000           0
